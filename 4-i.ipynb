# %% [raw]
# Scrape the details most watched tv series of all time from imdb.com.
# Url = https://www.imdb.com/list/ls095964455/
# You have to find the following details:
# A) Name
# B) Year span
# C) Genre
# D) Run time
# E) Ratings
# F) Votes

# %%
import bs4
import requests
from bs4 import BeautifulSoup

# %%
url='https://www.imdb.com/list/ls095964455/'

# %%
page=requests.get(url)

# %%
page
# Out:
# <Response [200]>

# %%
Name=[]
Span=[]
Genre=[]
Time=[]
Ratings=[]
Votes=[]

# %%
soup=BeautifulSoup(page.content,'html.parser')

# %%
name=soup.find_all('h3',class_='lister-item-header')
name[0:4]
# Out:
# [<h3 class="lister-item-header">
#  <span class="lister-item-index unbold text-primary">1.</span>
#  <a href="/title/tt0944947/">Game of Thrones</a>
#  <span class="lister-item-year text-muted unbold">(2011–2019)</span>
#  </h3>,
#  <h3 class="lister-item-header">
#  <span class="lister-item-index unbold text-primary">2.</span>
#  <a href="/title/tt4574334/">Stranger Things</a>
#  <span class="lister-item-year text-muted unbold">(2016– )</span>
#  </h3>,
#  <h3 class="lister-item-header">
#  <span class="lister-item-index unbold text-primary">3.</span>
#  <a href="/title/tt1520211/">The Walking Dead</a>
#  <span class="lister-item-year text-muted unbold">(2010– )</span>
#  </h3>,
#  <h3 class="lister-item-header">
#  <span class="lister-item-index unbold text-primary">4.</span>
#  <a href="/title/tt1837492/">13 Reasons Why</a>
#  <span class="lister-item-year text-muted unbold">(2017–2020)</span>
#  </h3>]

# %%
for i in name:
    Name.append(i.text)

# %%
Name[0:3]
# Out:
# ['\n1.\nGame of Thrones\n(2011–2019)\n',
#  '\n2.\nStranger Things\n(2016– )\n',
#  '\n3.\nThe Walking Dead\n(2010– )\n']

# %%
len(Name)
# Out:
# 100

# %%
time=soup.find_all('span',class_='runtime')

# %%
for i in time:
    Time.append(i.text)

# %%
Time[0:6]
# Out:
# ['57 min', '51 min', '44 min', '60 min', '43 min', '59 min']

# %%
len(Time)
# Out:
# 100

# %%
genre=soup.find_all('span',class_='genre')

# %%
for i in genre:
    Genre.append(i.text)

# %%
Genre[0:4]
# Out:
# ['\nAction, Adventure, Drama            ',
#  '\nDrama, Fantasy, Horror            ',
#  '\nDrama, Horror, Thriller            ',
#  '\nDrama, Mystery, Thriller            ']

# %%
len(Genre)
# Out:
# 100

# %%
span=soup.find_all('span',class_='lister-item-year text-muted unbold')

# %%
for i in span:
    Span.append(i.text)

# %%
Span[0:10]
# Out:
# ['(2011–2019)',
#  '(2016– )',
#  '(2010– )',
#  '(2017–2020)',
#  '(2014–2020)',
#  '(2013–2019)',
#  '(2017– )',
#  '(2005– )',
#  '(2014– )',
#  '(2012–2020)']

# %%
len(Span)
# Out:
# 100

# %%
ratings=soup.find_all('span',class_='ipl-rating-star__rating')

# %%
for i in ratings:
    Ratings.append(i.text)

# %%
Ratings
# Out:
# ['9.3',
#  '0',
#  'Rate',
#  '1',
#  'Rate',
#  '2',
#  'Rate',
#  '3',
#  'Rate',
#  '4',
#  'Rate',
#  '5',
#  'Rate',
#  '6',
#  'Rate',
#  '7',
#  'Rate',
#  '8',
#  'Rate',
#  '9',
#  'Rate',
#  '10',
#  'Rate',
#  '8.8',
#  '0',
#  'Rate',
#  '1',
#  'Rate',
#  '2',
#  'Rate',
#  '3',
#  'Rate',
#  '4',
#  'Rate',
#  '5',
#  'Rate',
#  '6',
#  'Rate',
#  '7',
#  'Rate',
#  '8',
#  'Rate',
#  '9',
#  'Rate',
#  '10',
#  'Rate',
#  '8.2',
#  '0',
#  'Rate',
#  '1',
#  'Rate',
#  '2',
#  'Rate',
#  '3',
#  'Rate',
#  '4',
#  'Rate',
#  '5',
#  'Rate',
#  '6',
#  'Rate',
#  '7',
#  'Rate',
#  '8',
#  'Rate',
#  '9',
#  'Rate',
#  '10',
#  'Rate',
#  '7.6',
#  '0',
#  'Rate',
#  '1',
#  'Rate',
#  '2',
#  'Rate',
#  '3',
#  'Rate',
#  '4',
#  'Rate',
#  '5',
#  'Rate',
#  '6',
#  'Rate',
#  '7',
#  'Rate',
#  '8',
#  'Rate',
#  '9',
#  'Rate',
#  '10',
#  'Rate',
#  '7.6',
#  '0',
#  'Rate',
#  '1',
#  'Rate',
#  '2',
#  'Rate',
#  '3',
#  'Rate',
#  '4',
#  'Rate',
#  '5',
# ...

# %%
a=Ratings[0::23]

# %%
a[0:2]
# Out:
# ['9.3', '8.8']

# %%
len(a)
# Out:
# 100

# %%
votes=soup.find_all('p',class_='text-muted text-small')

# %%
for i in votes:
    Votes.append(i.text)

# %%
Votes[0:2]
# Out:
# ['\nA\n|\n57 min\n|\n\nAction, Adventure, Drama            \n',
#  '\n            \n    Stars:\nEmilia Clarke, \nPeter Dinklage, \nKit Harington, \nLena Headey\n']

# %%
Votes
# Out:
# ['\nA\n|\n57 min\n|\n\nAction, Adventure, Drama            \n',
#  '\n            \n    Stars:\nEmilia Clarke, \nPeter Dinklage, \nKit Harington, \nLena Headey\n',
#  '\nVotes:\n1,732,832\n',
#  '\n15\n|\n51 min\n|\n\nDrama, Fantasy, Horror            \n',
#  '\n            \n    Stars:\nMillie Bobby Brown, \nFinn Wolfhard, \nWinona Ryder, \nDavid Harbour\n',
#  '\nVotes:\n792,301\n',
#  '\n18+\n|\n44 min\n|\n\nDrama, Horror, Thriller            \n',
#  '\n            \n    Stars:\nAndrew Lincoln, \nNorman Reedus, \nMelissa McBride, \nDanai Gurira\n',
#  '\nVotes:\n840,939\n',
#  '\n16+\n|\n60 min\n|\n\nDrama, Mystery, Thriller            \n',
#  '\n            \n    Stars:\nDylan Minnette, \nKatherine Langford, \nChristian Navarro, \nAlisha Boe\n',
#  '\nVotes:\n251,664\n',
#  '\nA\n|\n43 min\n|\n\nDrama, Mystery, Sci-Fi            \n',
#  '\n            \n    Stars:\nEliza Taylor, \nBob Morley, \nMarie Avgeropoulos, \nIsaiah Washington\n',
#  '\nVotes:\n210,553\n',
# ...

# %%
d=Votes[2::3]

# %%
d[0:3]
# Out:
# ['\nVotes:\n1,732,832\n', '\nVotes:\n792,301\n', '\nVotes:\n840,939\n']

# %%
len(d)
# Out:
# 100

# %%
Name=[]
Span=[]
Genre=[]
Time=[]
Ratings=[]
Votes=[]

# %%
import pandas as pd

# %%
df=pd.DataFrame({})

# %%
df['Name']=Name
df['Time Span']=Span
df['Genre']=Genre
df['Span']=Span
df['Ratings']=a
df['Votes']=d

# %%
df
# Out:
#                                                  Name    Time Span  \
# 0                \n1.\nGame of Thrones\n(2011–2019)\n  (2011–2019)
# 1                   \n2.\nStranger Things\n(2016– )\n     (2016– )
# 2                  \n3.\nThe Walking Dead\n(2010– )\n     (2010– )
# 3                 \n4.\n13 Reasons Why\n(2017–2020)\n  (2017–2020)
# 4                        \n5.\nThe 100\n(2014–2020)\n  (2014–2020)
# ..                                                ...          ...
# 95                        \n96.\nReign\n(2013–2017)\n  (2013–2017)
# 96  \n97.\nA Series of Unfortunate Events\n(2017–2...  (2017–2019)
# 97               \n98.\nCriminal Minds\n(2005–2020)\n  (2005–2020)
# 98           \n99.\nScream: The TV Series\n(2015– )\n     (2015– )
# 99       \n100.\nThe Haunting of Hill House\n(2018)\n       (2018)
#
#                                      Genre         Span Ratings  \
# 0   \nAction, Adventure, Drama              (2011–2019)     9.3
# ...

# %%
df.to_csv('toptvshows.csv')
