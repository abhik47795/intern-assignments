# %%
import selenium
from selenium import webdriver
from datetime import date
from datetime import datetime

# %%
driver=webdriver.Chrome(r"E:\DATA SCIENCE\chromedriver.exe")

# %%
driver.get('https://in.indeed.com/jobs?q=Business+Analyst&l=Mumbai,+Maharashtra&radius=0')

# %%
dt=[]
time=[]
titles=[]
companies=[]
locations=[]
Hir=[]
links =[]
ratings=[]
salaries = []
descriptions=[]

# %%
for i in range(0,19):
    
    jobs = driver.find_elements_by_xpath('//div[contains(@class,"clickcard")]')
    
    for job in jobs:
       
        now=datetime.now()
        time.append(now.strftime("%H:%M:%S"))
        today=datetime.today()
        dt.append(today.strftime("%y-%m-%d"))
        try:
            rating = job.find_element_by_xpath('.//span[@class="ratingsContent"]').text
        except:
            rating = "None"
        ratings.append(rating)
 
        try:
            salary = job.find_element_by_xpath('.//span[@class="salaryText"]').text
        except:
            salary = "None"
      
        salaries.append(salary)
        
        try:
            hir=job.find_element_by_xpath('.//td[@class="jobCardShelfItem urgentlyHiring"]').text
        except:
            hir="none"
            
        Hir.append(hir)
        
        try:
            location = job.find_element_by_xpath('.//span[contains(@class,"location")]').text
        except:
            location = "None"
        
        locations.append(location)
        
        try:
            title  = job.find_element_by_xpath('.//h2[@class="title"]//a').text
        except:
            title = job.find_element_by_xpath('.//h2[@class="title"]//a').get_attribute(name="title")
        titles.append(title)
        links.append(job.find_element_by_xpath('.//h2[@class="title"]//a').get_attribute(name="href"))
        companies.append(job.find_element_by_xpath('.//span[@class="company"]').text)
        
    
    try:
        next_page = driver.find_element_by_xpath('//a[@aria-label={}]//span[@class="pn"]'.format(i+2))
        next_page.click()

    except:
        next_page = driver.find_element_by_xpath('//a[@aria-label="Next"]//span[@class="np"]')
        next_page.click()
        
    
    print("Page: {}".format(str(i+2)))
# Out:
# Page: 2
# Page: 3
# Page: 4
# Page: 5
# Page: 6
# Page: 7
# Page: 8
# Page: 9
# Page: 10
# Page: 11
# Page: 12
# Page: 13
# Page: 14
# Page: 15
# Page: 16
# Page: 17
# Page: 18
# Page: 19
# Page: 20

# %%
len(ratings)
# Out:
# 169

# %%
len(dt)
# Out:
# 169

# %%
len(time)
# Out:
# 169

# %%
len(companies)
# Out:
# 169

# %%
len(titles)
# Out:
# 169

# %%
len(locations)
# Out:
# 169

# %%
len(links)
# Out:
# 169

# %%
len(Hir)
# Out:
# 169

# %%
len(links)
# Out:
# 169

# %%
len(salaries)
# Out:
# 169

# %%
try:
    descriptions=[]
    for link in links:
        driver.get(link)
        jd = driver.find_element_by_xpath('//div[@id="jobDescriptionText"]').text
        descriptions.append(jd)
except:
    print("--")
# Out:
# --

# %%
len(descriptions)
# Out:
# 169

# %%
descriptions
# Out:
# ['Responsibilities\nPerson will be responsible for documenting client requirements and also creating a business blueprint document which will be shared with client and project stakeholders\nPerson with experience on Salesforce Marketing Cloud will be an advantage.\nWill need to understand technical solutions and document used cases. Will be required to build a deep understanding of the SFMC solution -End - to - end implementation will include requirement gathering / discovery workshop in order to understand the exact requirement from the client\nWill need to interact with project stakeholders – client and internal stakeholder effectively\nShould be able to create project Blue print and maintain the same across clients\nShould be able to work across projects\n\nDesired Skills and Experience\nShould have good written and verbal English communication skills\nShould be good team player\nDeep knowledge of Salesforce Marketing Cloud and channels (preferable)\nAbility to deliver complex assignments within challenging timelines',
#  "Job Description\nPlay CEO’s office Business Partner role to help business leaders deliver strategy implementation charters through dedicated support and ownership. The incumbent will be required to multi-task, conceptualize effective strategies, help create feasibility reports and execute new projects\nRoles & Responsibilities\nResponsibilities :\nAssist the CEO with inputs and data required for making strategic decisions and coordinate the strategy planning exercise\nBusiness data analysis and market benchmarking -Maintain ongoing analysis of competitive landscape and industry trends. Develop strategic recommendations using intelligence to achieve and sustain market leadership\nAssist in preparation of board / investor presentations and business plan, business reports including tracking, monitoring and following up on open action items\nDrafting the agenda and producing accurate and timely Board minutes at each meeting\nEligibility\nExperience :\n2 – 3 yrs of experience post qualification in a similar role\nNBFC/Banking experience preferred\nTechnical Skills required:\nProficient in MS Office Suite\nData Analysis and inference development\nPersonal Attributes:\nExcellent written & oral communication skills A motivated self-starter with strong interpersonal skills\nStrong presentation skills\nShould have good sense of time management, planning & organizing, judgement and analysis\nAbility to perform under stringent deadlines\nMultitasking abilities\nShould possess eye for details\nFormal Qualification :\nCA/ MBA from top tier institutes\nJob Type: Full-time\nSchedule:\nDay shift\nExperience:\nbusiness analysis: 3 years (Required)\ntotal work: 2 years (Preferred)\nEducation:\nMaster's (Preferred)",
#  'Job Code :\nMRF/IT-5805/2020\nExperience :\n4.00 - 6.00 Yrs\nQualification :\nB.E\nMandatory Skills :\nBusiness Analyst\nJob Description :\n\nMust have hands-on experience of Trade Finance domain.\nShould have well versed understanding of different Trade Finance products, and must be aware of field level technicalities related to different products.\nShould have good understanding of different documents involved in Trades.\nMust have worked with some bank (preferably Axis) in trade finance.\nShould be able to work on MS Office (Excel and Word).\nShould be able to work under extreme pressure of deliverable and can face client.',
#  "About EY\nAs a global leader in assurance, tax, transaction and advisory services, we hire and develop the most passionate people in their field to help build a better working world. This starts with a culture that believes in giving you the training, opportunities and creative freedom to make things better. So that whenever you join, however long you stay, the exceptional EY experience lasts a lifetime.\n\n\nAnalyst – Risk - Internal Audit\n\nThe opportunity\n\nThe objective of our advisory risk services is to provide clients with a candid and reliable overview of their risk landscape. Our solutions can be used by our clients to build confidence and trust with their customers, the overall market and when required by regulation or contract. You will be responsible for executing client related engagements in the areas of governance, risk & compliance (GRC), internal audits, process reviews, standard operating procedures, enterprise risk management, revenue assurance and other Business Risk Services related solutions.\n\nYour key responsibilities\nExecution on client engagement – Ensure quality delivery as per client requirements.\nContinuously strive towards exceeding client & team expectations and work on increasingly complex assignments.\nConduct research and prepare client presentations, information memorandums and thought leadership documents.\nContribute to advisory engagements in the capacity of a team member - deliver quality output within assigned timelines.\nAttend L&D programs and exhibit through knowledge of advisory methodology and consulting attributes.\nKeep abreast with developments in business related areas and assist team leaders/managers in preparing client decks.\nSector focus (basic understanding of the industry, trends, issues/challenges & key players) based on the industry group alignment.\nExhibit initiative and participate in corporate social and team events. Understand business & industry issues / trends. Identify areas requiring improvement in the client's business processes to enable preparation of recommendations.\nEnsure compliance with engagement plans and internal quality & risk management procedures.\nDevelop strong working relationships with client (process owner/functional heads).\n\nSkills and attributes for success\nDetermine that the work delivered is of high quality.\nAnticipate and identify engagement related risks and escalate issues as appropriate.\nAssist team members, Seniors and Managers in developing new methodologies and internal initiatives.\n\nTo qualify for the role you must have\nA Bachelor’s degree in Commerce, Management, Accounting, Finance or Economics and other graduation streams or a related discipline\nWe would expect for you to be available to travel outside of their assigned office location at least 50% of the time.\nIdeally, you’ll also have\nGood communication skills\n\nWhat we look for\n\nWe’re looking for passionate leaders with strong vision and a desire to stay on top of trends in the risk industry. If you have a genuine passion for helping businesses achieve their full potential, this role is for you.\nWhat working at EY offers\nEY is committed to being an inclusive employer and we are happy to consider flexible working arrangements. We strive to achieve the right balance for our people, enabling us to deliver excellent client service whilst allowing you to build your career without sacrificing your personal priorities. While our client-facing professionals can be required to travel regularly, and at times be based at client sites, our flexible working arrangements can help you to achieve a lifestyle balance.",
#  'Designation:\nBusiness System Analyst\nJob Location:\nDelhi/NCR or Mumbai\nYou will be responsible for implementation of Newgen Products & Solutions & customer engagements.\nThe broad responsibilities include:\n\uf0d8 Post-Sales Engagement Management with the clients along with the role of Business & System Analyst.\n\uf0d8 Documenting high level and detailed requirements using elicitation techniques such as scenarios (use cases) / prototyping.\n\uf0d8 Producing a project definition/project initiation document clearly defining scope and project objective.\n\uf0d8 Interpreting and construct basic tables in database related with Queue / External Variables.\n\uf0d8 Executing a user acceptance / system test script & awareness about project risks, issues, assumptions and dependencies & change control processes especially in relation to requirements documentation.\n\uf0d8 Resolving complex requirement conflicts through effective stakeholder engagement.\n\uf0d8 Effectively presenting options and recommendations to stakeholders.\nProfile Requirements:\n\uf0d8 You should be a B.E/B. Tech/Bsc/BCA and MBA from a reputed institute, with 1 to 3 years of experience as system analyst for software products like ERP, CRM, BPM, ECM. You must have:\n\uf0d8 You should have 60% or more throughout your academic profile.\n\uf0d8 Understanding of the software product market dynamics and software development processes.\n\uf0d8 Possess excellent relationship, communication and customer relationship management skills.\n\uf0d8 Exhibit strong leadership qualities through quick decision-making and change management & strong analytical ability.\n\uf0d8 Good experience in Ms-Office and documentation skills.\n\uf0d8 Willingness to travel for Short term/Long term within India/Outside India and work as per project requirements.\nExperience:\n1 - 3 years\nJob Type: Full-time\nSchedule:\nDay shift\nExperience:\nwork: 1 year (Preferred)\ntotal work: 1 year (Preferred)\nEducation:\nSecondary(10th Pass) (Preferred)',
#  'Group Company: Angel Broking Limited\nDesignation: Business Analyst (ABL_EB_253), Business Analyst (ABL_EB_35)\nPosition description:\nDefine specifications and business requirements for web, desktop & mobile applications from internal & external stakeholders. Create User stories/Acceptance criteria.\nWork with all the stakeholders to understand the pain areas and needs. Identify opportunities to address pain points and provide seamless experience for end users.\nClosely work with technology team and other stakeholders to communicate the requirements and develop features.\nCreate wireframes, partner with UI/UX designers to develop great designs and user experience.\nPerform quality assurance; make sure the newly developed solutions are working as per the acceptance criteria.\nSupport production issues. Perform RCA and identify solutions for customer complaints and issues.\nConstantly be on the lookout for ways to improve, discover issues and deliver highest value to the customer.\nResearch and come up with Innovative ideas to improve the application and customer experience.\nCompetition landscape tracking. Analyze leading market players and competitors to gain insights and implement innovative solutions to gain competitive advantage over other apps.\nPrimary Responsibilities:\nGather business requirement from internal & external stakeholders, translate into technical & functional specification & perform UAT.\nReporting Team\nReporting Designation: Senior Lead - Product Initiatives (ABL_EB_134)\nReporting Department: Digital Initiatives (2513_1)\nRequired Skills:\nStrong written and verbal communication skills. Technical Writing.\nStrong Analytical and technical skills. Should understand SQL, APIs, Application Development.\nStrong knowledge of SDLC process. Experience in working in Agile/Scrum setup.\nKnowledge of JIRA & Confluence Tools will be an added advantage.',
#  'Role – Business Analyst – Calypso\nMode : Permanent\nLocation – Mumbai\nExperience: 9 to 15 Years\nJob Description\nGood experience in Front, Middle & Back office.\nGood experience in managing client, requirement gathering, GAP Analysis, testing.\nShould have hands on experience in client management like resource on boarding, project planning etc.Job Description.\nOpen to work in 2nd Shift.\n\nJob Features\nLocation\nMumbai\n\nExperience\n9 - 15 Years',
#  'Group Company: Angel Broking Limited\nDesignation: Specialist Business Analyst - Payments (ABL_SS_538)\nPosition description:\nLead and implement Payment (Net-banking, UPI, Debit/Credit cards, Wallets) related changes, enhancements and innovative solutions.\nDefine specifications and business requirements for web, desktop & mobile applications. Create User stories/Acceptance criteria.\nWork with all the stakeholders to understand the pain areas and needs. Identify opportunities to address pain points and provide seamless experience for end users.\nClosely work with the technology team, vendor partners, aggregators, and other stakeholders to communicate the requirements and develop solutions.\nCreate wireframes, partner with UI/UX designers to develop great designs and user experience.\nPerform quality assurance; make sure the newly developed solutions are working as per the acceptance criteria.\nSupport production issues. Perform RCA and identify solutions for customer complaints and issues.\nConstantly be on the lookout for ways to improve, discover issues and deliver highest value to the customer.\nResearch and come up with Innovative ideas to improve the application and customer experience.\nCompetition landscape tracking. Analyze leading market players and competitors to gain insights and implement innovative solutions to gain competitive advantage over other apps.\nPrimary Responsibilities:\nWork with all the stakeholders to understand the pain areas and new ideas. Identify opportunities to address issues and provide seamless experience for end users.\nReporting Team\nReporting Designation: Head - Mobile and Payment Platforms (ABL_SS_380)\nReporting Department: Product Development (2171)\nRequired Skills:\nBE/B-Tech/MBA or relevant degrees, with 6-10 years of experience\nStrong knowledge of Payments system (Netbanking, UPI, Aggregators etc)\nStrong knowledge of BFSI domain & Trading Platform (Capital Markets / Cash / F&O / Commodity / Currency / IPO / Mutual Funds / Insurance etc.)\nStrong written and verbal communication skills. Technical Writing.\nKnowledge of UPI / Netbanking / Debit cards / Credit Cards / Wallets / Payment Gateways Integration.\nStrong Analytical and technical skills. Should understand SQL, APIs, Application Development.\nStrong knowledge of SDLC process. Experience in working in Agile/Scrum setup.\nKnowledge of JIRA & Confluence Tools will be an added advantage.\nKnowledge of Payments operations systems is a plus point.',
#  'Group Company: Angel Broking Limited\nDesignation: Specialist - Business Analyst (ABL_SS_310)\nPosition description:\nDefine specifications and business requirements for web, desktop & mobile applications. Create User stories/Acceptance criteria.\nWork with all the stakeholders to understand the pain areas and needs. Identify opportunities to address pain points and provide seamless experience for end users.\nClosely work with the technology team and other stakeholders to communicate the requirements and develop features.\nCreate wireframes, partner with UI/UX designers to develop great designs and user experience.\nPerform quality assurance; make sure the newly developed solutions are working as per the acceptance criteria.\nSupport production issues. Perform RCA and identify solutions for customer complaints and issues.\nConstantly be on the lookout for ways to improve, discover issues and deliver highest value to the customer.\nResearch and come up with Innovative ideas to improve the application and customer experience.\nCompetition landscape tracking. Analyze leading market players and competitors to gain insights and implement innovative solutions to gain competitive advantage over other apps.\nPrimary Responsibilities:\nWork with all the stakeholders to understand the pain areas and new ideas. Identify opportunities to address issues and provide seamless experience for end users.\nReporting Department: Product Development (2170)\nEducational qualifications preferred Academic score:\nRequired Skills :\nStrong knowledge of SDLC process. Experience in working in Waterfall/Agile/Scrum setup.\nStrong written and verbal communication skills.\nBFSI/Trading domain will be a plus point\nStrong Analytical and technical skills. Should understand SQL, APIs, and Application Development.\nSelf-driven, passionate about building products and digital solutions, customer centricity.\nKnowledge of JIRA, Confluence or similar project management tools\nNCFM, Scrum Master, Product Owner related certifications (Good to have).',
#  'Define operational/business processes, Manage new initiatives/opportunities that may involve coordination between the sales channel and other organizations, such as Marketing, Product Management, IT, etc. Review current tools and processes being used and identify opportunities for automation of the processes by implementing necessary tools with the help of technology. Manage and co-ordinate the overall operation of the BU to support large complex bids with customers. Drive the collection and analysis of operational data, conduct MIS and convert data into value for customers and Internal teams in the areas of Monitoring and Reporting, Sales enablement, Support to Product management, Maturity of decision support offerings etc. Provide reviews and financial/non-financial performance reporting to enable the business to achieve its long term objectives, Minimize costs of operations for business. Keep tab on benchmarks / budgets and work towards cost reduction. Maximize operational efficiency around processes by driving continuous process improvement initiatives. Identify and highlight the operational issues related to customers, vendors (external as well as internal) and ensuring resolution. Responsibilities may include, but are not limited to, the following: Sales process activities of the business segment- Billing, Orders, Agreements, Bilaterals, swaps, Market Management etc. ; Ensuring on-time customer delivery through accurate and detailed operating plans. Conduct operations management activities such as business planning, operational plans, project management, communications, etc. for defined business segment.\nBroad outline of the Role\nResponsible for administrating new initiatives and business processes/opportunities that may involve coordination between the sales channel and other organizations, such as Marketing,etc. Regularly participate in important projects or activities as a full contributing team member, is able to proactively identify important issues or risks, seeks the appropriate level of guidance and advice to ensure delivery of quality outcomes. Operational role which is responsible for delivering results that have direct impact on the achievement of results within Business Operations/ Commercial Operations. Works under direct supervision.Work efficiently and productively with broad instruction. Able to identify problems and provide inputs to improve, change or adapt existing methods and techniques drawing from personal experiences and feedback. Actively acquires more complex skills, techniques, operating practices, knowledge of abstract concepts in order to progress toward full proficiency in the field of specialisation.Has skills and knowledge that will allow them to adapt to effectively deal with unfamiliar issues, challenges, problems within their field of specialisation. Education: Graduate Experience: 0-4 years\nPurpose - Broad objective of the role\nOperating Network - Key External\nOperating Network - Key Internal\nSize and Scope of Role - Financial\nSize and Scope of Role - No. of direct reports\nSize and Scope of Role - Total team size\nSize and Scope of Role - Other size parameters\nMinimum qualification & experience\nOther knowledge/skills\nKey Responsibilities\nTechnical Competencies\nKnowledge / Skills\nCommunication Skills',
#  'The purpose of this role is leading, developing and mentoring the Experience Design team into the creation and delivery of a unified Experience Design vision within the organisation, whilst being the ultimate champion of the user throughout the creative process. An Experience Design Director easily grasps the needs of an audience and can balance those against the client’s business goals, enabling them to translate that complex relationship into effective and compelling experiences and interactions, infused with best practices and visionary insights earned through years of hands-on experience.\nJob Title:\nBusiness Analyst\nJob Description:\nKey responsibilities:\n• Provides overall direction for User Experience by analysing business objectives and customer needs as well as developing, communicating and implementing business strategies and practices whilst driving continuous improvement of user experience tools, documentation and process\nIdentifies and capitalises on improvement opportunities, promoting a user-oriented environment within the organisation, as well as developing and leveraging internal and external partnerships and networks to maximise the achievement of the client’s business goals\nStays current with latest technology and human interactions, whilst looking for opportunities to learn and contribute to ideas and innovations within the discipline and sponsoring the Experience Design team’s continuous learning\nCreatively supports the effective use of technology and its applications to solve business problems\nLeads, mentors and is a key contributor on pitch teams\nLeads the Experience Design team through regular work reviews, check-ins, goal planning and training. Mentors direct reports, creates a supportive culture and encourages people to consistently excel\nIdentifies opportunities to create high profile blog posts, industry articles, internal presentations and industry presentations\nLocation:\nMumbai\nBrand:\nFractal\nTime Type:\nFull time\nContract Type:\nPermanent',
#  "Job Responsibilities\nStudy user requirements and design user experiences keeping simplicity in mind\nAnalyze data to derive patterns that facilitate solution building and drive automation\nDesign and develop software solutions to problems in the financial research domain ranging from data analysis, algorithms and approaches for developing insightful analysis\nUnderstand and apply financial concepts to technology solutions for business problems Work with different functional groups to get a better understanding of the challenges involved and devise optimized solutions\nGet involved in testing of the builds\nDrive adoption of the platform among target customer groups by sharing more info on various features / conducting sessions\nWork in a fast-paced agile development environment\nIdeal Candidates\nShould love creating solutions involving large amounts of data for complex analytical problems\nExperience in the financial domain, specifically in the investments and insurance space\nExposure to RDBMS and ability to write optimized queries will be a plus\nShould have a good grasp of technology; actual hands-on experience in a technology is a plus\nBE / BTech from premier institutes with a first class academic track record. An MBA / CFA will be a plus.\nAdvantage working with us: -\nWorking with Start-up\nFlexible working hours\nHigh growth for performer\nAcademic Qualifications BE/ B. Tech with 2-5 years of experience in the Software Industry and good academics throughout. An additional finance degree (MBA / CFA) would be a plus.\nLocation and Benefits\nThe candidate will operate from our Mumbai office. We promise a professional working environment with ample fun factor!\nJob Type: Full-time\nPay: ₹500,000.00 - ₹600,000.00 per year\nSchedule:\nMorning shift\nExperience:\nTotal: 3 years (Required)\nwork: 1 year (Preferred)\nfinancial Domain: 3 years (Required)\nData analytical: 3 years (Required)\nEducation:\nMaster's (Required)",
#  "Hiring Business Analyst\nQualification required – B. Tech/ MCA\nYear of experience – 1 to 1.5 year\nIndustry Experience: Life Insurance (Projects UAT, Life Asia, Pay Connect Payment system)\nRoles & responsibilities:\n1. Understanding requirement from users for all accounts related systems. Preparing BRD, FSD & coordinating with users & IT.\n2. Coordination with IT for budgeting projects & finalizing efforts.\n3. Preparing test scenarios & testing data for UAT.\n4. Testing on UAT environment.\n5. Handling Production related issues & support users.\n6. Good understating of project management flow.\n7. Good communication skills.\n8. Skill to handle multiple projects UAT.\n9. Follow up with multiple teams to complete project.\nJob Type: Full-time\nSalary: Up to ₹1.00 per year\nSchedule:\nDay shift\nExperience:\nbusiness analyst: 1 year (Required)\nEducation:\nBachelor's (Required)\nLocation:\nMumbai, Maharashtra (Required)\nWork Remotely:\nTemporarily due to COVID-19",
#  "Job Description: -\nThe analyst will work independently to understand the requirements and deliver the documents\nInteract directly with our internal users to gather requirements and understand business needs\nTranslate business needs into requirement documents\nWork with developers to clarify/refine/elaborate requirements as the technical implementation progresses\nFunctional design in collaboration with the Data, Technical and Integration Architects to ensure the functional and technical design is robust and meets both functional/non-functional requirements\nDiscuss complex business issues and provide recommendations on action to senior stakeholders and IT managers\nWork with the QA department to ensure the delivery of quality software\nParticipate in planning for the creation and ongoing maintenance of schedules, risks, and issues\nUAT testing\nSkills/Knowledge: -\nExcellent writing skills, specifically in the creation of requirement documents\nExcellent communication skills with an outgoing, diligent and proactive attitude\nFirst-hand experience with creating new software systems, from inception to deployment.\nKnowledge of MYSQL & DBMS concept will be additional Benefit\nExpected Start Date: 1/1/2021\nJob Type: Full-time\nSalary: From ₹250,000.00 per year\nSchedule:\nMonday to Friday\nExperience:\nBFSI domain: 1 year (Required)\nbusiness analyst: 2 years (Preferred)\nEducation:\nBachelor's (Preferred)\nCOVID-19 Precaution(s):\nRemote interview process\nVirtual meetings",
#  'The Upstox Story:\nOne of the fastest growing stock broking companies and first brokers in India to introduce commission-free trading for investors. Our customers enjoy zero brokerage on equity delivery trades and a flat Rs. 20 per order pricing model on all other segments.\nWe are on our way to become the leader in low-cost brokerage and No.1 stock broker in the country. We scaled from a customer database of 25k customers in 2017 to 2 Lakh customers in 2019 to 2+ Million customers now.\nThe company will continue to be driven by its guiding principle of making trading in stock markets simple and affordable for all.\nCompany’s focus on high-design and leading-edge technology seeks to revolutionise the online trading industry in India, all at disruptive price points. Backed by Ratan Tata, Upstox had raised $4 million in Series A funding in early 2016 that was led by Kalaari Capital. The round also saw participation from health care tech firm GVK Davix Technologies Pvt Ltd. US-based investment firm Tiger Global Management invested $25 million in the company in September 2019 in a Series B funding round.\nWe have a team of highly skilled technology and finance professionals, and are currently looking for highly motivated field experts to be part of our high-energy team.\n\nWhere did it all start:\nOur journey started in 2010, when Raghu Kumar (RK), Ravi Kumar (RK) and Shrinivas Viswanath (SV) founded RKSV Securities India Pvt. Ltd., a proprietary trading firm. In 2012, we opened up to the general public by entering the retail brokerage space as a discount-broking firm. The dream was to make stock-market investing affordable and easy for all Indians, while ensuring that they also made profits from the venture. In 2016, we rebranded ourselves as Upstox. The same year, we also raised about $4 million in the first round of funding, backed by Mr. Ratan Tata, Kalaari Capital, and GVK Davix.\n\nPosition: Business Analyst\n\nAbout the Team:\n\nWe are a Formula-1 team where every millisecond counts. Here, we are continuously innovating and building highly scalable backend systems and strategies that gives a seamless experience to our customers even during large volume of traffic hitting our systems\n\nA glimpse of what we do:\n\nCreating and improving multiple products via continuous delivery.\nEmbrace and enable DevOps culture within the organization.\nData driven approach to build new products and features.\nBuild new tech innovations to improve business processes and enable our various departments to help service our customers better.\n\nRoles & responsibilities:\n\nDevelop business requirements for aligned business units and the enterprise as a whole Impact analysis, Gap analysis, interacting with client for clarifications and knowledge transition to development team.\n- Creating business requirement document (BRD), Functional Specification Document (FSD), creating Use case diagrams, workflow analysis, supporting Project estimation, Analysing Business Process - -Model document, User stories, traceability matrix.\nBuilding use cases and UML diagrams.\nContribute to solution selection for supported business units as part of the enterprise strategy.\nPropose solution based on the requirements and organization policies.\nImplement and manage change when necessary to meet project outputs.\nWriting SQL queries for end-to-end data mapping.\nProvide knowledge transfer walkthroughs and resolve issues effectively for the client and backend team.\nWork with external software and service partners and their support staff as required.\n\nRequirements:\n\nShould have 4+ Years of experience as Business Analyst.\nShould have experience working on Back-office Application.\nShould have good experience in creating BRD (Business Required Documents), FRD (Functional Required Documents).\nShould have Experience of collaborating with developers and subject matter experts to build the technical vision and analyse trade-offs.\nShould have good experience on p ...
#  'As a business analyst, you will be a leading contributor in the implementation of various projects in Data Collections team. This role requires significant interaction with both upstream and downstream stakeholders across Technology, Data, Products, Sales/Service, and Research.\nWe are looking for an individual who possesses strong domain expertise in data collection domain, an ability to follow data analyst’s requirements and write user stories to implement the projects like enhancements/addition of new dataset, data next gen implementation etc.\nThis position reports to the Tech Manager of the Data Collections.\nResponsibilities :\n• Work within an Agile software development framework, develop business requirements and user stories refined and validated with customers and stakeholders, prioritize the backlog queue across multiple projects and workstreams, and ensure high quality execution working with development and business analyst squad members.\nWork with internal project stakeholders to define and document project scope, plan product phases/ versions, Minimum Viable Product, and overall product deliveries\nWork with other product owners from across the data collection organization to develop a product integration vision that supports and advances their business goals\nWork with cross-functional leaders to determine technology, design, and project management resource requirements to execute and delivery on commitments. Proactively communicate project delivery risks to key stakeholders to ensure timely deliverables\nOwn the tactical roadmap, requirements, and product development lifecycle for a squad to deliver high performing data collection applications to our clients\nUnderstand business, operations and technology requirements, serving as a conduit between stakeholders, operations, and technology teams\nRequirements :\n5+ years of working experience as Business Analyst for managing products/applications catering to equity data collection\nGood understanding of equity fundamental and non-fundamental datasets like financial statement, notes to account, company, personnel and price etc.\nUtilizes user research, product usage data, client services, sales and direct user interactions to identify unmet user needs and opportunities for improvement\nShould have working experience on creating Product Roadmap, Project Scope, Requirement Gathering and documenting\nShould have experience in working with different teams – Global product manager(s), development team(s), test team(s), product stakeholders\nWorking Agile Experience – Scrum methodology, JIRA or equivalent story writing tool, Product Backlog, Sprint Backlog, Story Estimation and Prioritization, creation of user stories, acceptance criteria\nActs as voice of the user within the development organization\nShould be able to clearly communicate the benefits of the product, discovery questions to ask, and answer "the why" to prospective clients\nUtilizes user research, product usage data, client services, direct user interactions to identify unmet user needs and opportunities for improvement\nA bachelor\'s degree is required; CFA or an equivalent certification will be an advantage\nA demonstrated ability to complete analysis and document requirements for multiple complex projects concurrently\nExcellent communication and strong inter-personal skills, time management/organization, and troubleshooting, good analytical and problem-solving skills\nA proven record in supporting large projects with aggressive timelines and wide, challenging scope.\nSelf-directed and detail-oriented.\nStrong knowledge of software development processes and methodologies\nGood to Have :\nExperience in capital market or financial services industry\nEOE Statement : Morningstar is an equal opportunity employer\nI10_MstarIndiaPvtLtd Morningstar India Private Ltd. (Delhi) Legal Entity',
#  'We are looking out for Sr. Business Analysts who are technically sound with good communication skills and a close fit to the job description below:\nPrimary (Essential) Technical Skills desired:\nSkilled in requirement gathering and articulating\nShould have knowledge creating Requirement documents and Functional Test case documents\nExecuting Functional testing and reporting defects\nTaking responsibility of the solution to be delivered to the customers using our product offering, from the requirement confirmation stage up to the final customer acceptance stage\nCarry out customer business requirement analysis using Requirement Workshops, Conference Room Pilots\nConceptualize the solution using our product offering to meet the requirements of the customer\nDiscuss, present to customer scenarios to the customer of solutions to meet the requirements of the customer. Get customer to agree on a chosen scenario\nLead the development team to build the proposed solution using the available product offering\nLead the engagement team to get the final solution tested and approved\nSoft / Behavioral Skills:\nAnalytical skills to carry out sessions with the customer personnel to think through proposed solution\nAbility to conceptualize\nGood written and oral communication\nAbility to interact with the senior management of the customer\nAbility to lead a team of development members\nOverall management skills to ensure the customer relationships remain under control\nConfident, Responsible and High Initiative Driven\nStrong in problem solving and quick in decision making\nEducational Qualification:\nMBA / MMS / PGDBA (mandatory first class throughout in academics)\nExperience:\n5 to 9 years\nJob Location:\nMumbai / Pune (May get posted at client site across the world during the period of assignment. The job may involve travel.)',
#  'We are looking out for Business Analysts who are technically sound with good communication skills and a close fit to the job description below:\nPrimary (Essential) Technical Skills desired:\nSkilled in requirement gathering and articulating\nShould have knowledge creating Requirement documents and Functional Test case documents\nExecuting Functional testing and reporting defects\nTaking responsibility of the solution to be delivered to the customers using our product offering, from the requirement confirmation stage up to the final customer acceptance stage\nCarry out customer business requirement analysis using Requirement Workshops, Conference Room Pilots\nConceptualize the solution using our product offering to meet the requirements of the customer\nDiscuss, present to customer scenarios to the customer of solutions to meet the requirements of the customer. Get customer to agree on a chosen scenario\nLead the development team to build the proposed solution using the available product offering\nLead the engagement team to get the final solution tested and approved\nSoft / Behavioral Skills:\nAnalytical skills to carry out sessions with the customer personnel to think through proposed solution\nAbility to conceptualize\nGood written and oral communication\nAbility to interact with the senior management of the customer\nAbility to lead a team of development members\nOverall management skills to ensure the customer relationships remain under control\nConfident, Responsible and High Initiative Driven\nStrong in problem solving and quick in decision making\nEducational Qualification:\nMBA / MMS / PGDBA (mandatory first class throughout in academics)\nExperience:\n2 to 5 years\nJob Location:\nMumbai / Pune (May get posted at client site across the world during the period of assignment. The job may involve travel.)',
#  'Understand the client process and associated data to help the project team with actionable insights\nDocumenting client requirement and create scope and BRD documents\nCreate project planner and sending out regular updates after taking follow up\nUnderstanding the use cases and process details and coming up with business solutions\nSupport the project team with stunning data visualization for client presentations\nPrepare the power point readouts with analysis to the clients',
#  "You will be expected to develop a strong understanding of the unique processes, system data, compliance responsibilities and workflow of each line of business (LOB) request, while maintaining and finding solutions that adhere to standardized processes, aligned metrics, and the overall strategy of the CCB Operations and Webstats productized tool. You will assess and manage changes to business models or operating strategies, update reporting calculations, and create proof of concept results to ensure data accuracy as needed. You will also be accountable for recognizing opportunities and recommending enhancements to existing/ new process flow(s) to improve effectiveness, efficiency and quality of the customer experience and performance management.\nInternal and External Description:\nSeasoned and diverse experience with business analysis\nKnowledge of effective project management and principles of Agile\nKnowledge of Contact Center, Workforce, and Back Office Dynamics\nUnderstanding of CCB Operations Lines of Business needs and processes\nAbility to consult and collaborate with others on solutions and cross impacts\nProven competency in developing, reporting, and analyzing business data\nExcellent analytical, problem solving, and time management skills\nDemonstrates critical thinking approach to problem solving\nExperience in workflow analysis and documentation\nOutstanding communication and presentation skills\nStrong teamwork and client management skills\nIdentifies and performs root cause analysis on process breaks, strategy enhancements and implement solutions\nStrong testing experience and discipline\nCreates environment of reliable data, transparency of issues, escalation and accountability\nAdjusts approach when necessary, in light of new findings, to ensure appropriate focus and coverage\nIdentifies internal process opportunities and initiate strategic plans\nDevelops recommendations to strengthen internal controls and improve operational efficiency\nUtilizes knowledge of business to level set the issues and escalate as appropriate\nMay lead various ad hoc projects\n\nInternal and External Qualifications:\nBachelor's Degree or equivalent work experience\nAdvanced SQL skills\nProven ability to analyze, understand large and/or complex data\nAbility to provide evidence of data query and data analytics work produced\nStrong experience with data transformation tools. (examples: Alteryx and Python )\nExperience or working knowledge with Business Intelligence (BI) and data visualization tools (examples: Tableau, Cognos, Kibana/Elastic Search, Gaia)\n2+ years working knowledge required in the following:\nFinancial Services Call/Contact Center industry\nKnowledge of various call/contact center solutions (Telephony, IVR, Scheduling, Call Recording, Reporting/MIS Tools, KANA Email, Back Office Tools, Customer Experience drivers)\nBusiness analysis, reporting of business data, problem identification, resolution and root cause analysis\nData marts, data relationships, query techniques/strategies/optimization\nProven competency in writing requirements and designing reports\nAbility to interpret and create functional usage mock-up and process flows\nPresentation/communication/delivery skills- written and verbal\nEffective project management and multi-assignment handling skills\nCustomer relationship and experience management\nTeam work contributing beyond core role and responsibilities\n\nPreferred Skills:\nMinimum 2-3+ years of process improvement experience\nAbility to interact with all levels of management and business partners\nProven presentation creation and delivery skills\nAbility to work independently with minimal supervision\nMust be able to effectively handle competing priorities and have the ability to work as a part of multiple teams\nMust have outstanding attention to detail and ability to learn complex processes that affect various functions and business units within Chase\nExcellent oral and written communication skill ...
#  "Business Data Analyst / Business Systems Analyst\nJPMorgan Chase & Co. (NYSE: JPM) is a leading global financial services firm with assets of $2.6 trillion and operations worldwide. The firm is a leader in investment banking, financial services for consumers and small business, commercial banking, financial transaction processing, and asset management. A component of the Dow Jones Industrial Average, JPMorgan Chase & Co. serves millions of consumers in the United States and many of the world's most prominent corporate, institutional and government clients under its J.P. Morgan and Chase brands. Information about JPMorgan Chase & Co. is available at www.jpmorganchase.com .\nThe Legal Department of JPMorgan Chase & Co is responsible for the provision of legal services to the Corporation and is organized by practice groups that generally align with the Corporation's lines of business and corporate staff areas. This structure encourages legal teams and businesses and staff areas to discuss legal, regulatory and business developments effectively and in a timely manner.\nLegal' s Office of the General Counsel (OGC) supports the Legal department's delivery of legal services. It sets the standards for the department's centralized processes and controls, delivers tools the department uses to work efficiently and effectively, and drives the department's change agenda with data, technology, innovation, legal knowledge and a client-centric approach.\nRole Description\nAs a Business Data Analyst within the ELA Product Management Team, you will work with Product owners to document user stories, participate in planning sessions and work with developers, business SME's and other team members to analyze user stories and requirements. You will create test cases, test plans, and other test artifacts in addition to executing test cases and triaging defects. Performing analysis of business requirements and system specifications in this role will be critical. In addition, you will provide specific details on issues; working with Product owners and ELA Technology team to track and verify resolution of issues. You will also own the creation and delivery of training to business functions on new enhancements and functionality\nKey Responsibilities\nDocument user stories and acceptance criteria along with the Product owners\nEffectively manage multiple streams of work and deliver high-quality product in a timely manner\nDocument UAT scenarios and test scripts for every sprint/ release\nPerform pre-UAT testing to ensure defects are identified and closed prior to UAT\nTrack and triage UAT defects and prioritize resolution with business and technology\nManage end to end UAT process from kick-off meetings to closing UAT\nCreate UAT meeting decks and provide supporting documents to facilitate testing\nCreate sample test data in UAT to facilitate UAT testing\nCreate training guides, one-pagers and job-aids for new enhancements\nConduct trainings on new functionality and enhancements for business functions\nKeep the training material ever-green based on the latest functionality\nWork with cross-functional teams like ELA reporting, document dependencies and provide solutions\nSkills Required\nMinimum 3-5 years of experience working in Agile teams and running UAT\nMinimum 1-3 years of experience in creating and facilitating user trainings\nCommunicate effectively (verbal and written) on both a technical and business level\nDemonstrate ability to gather and understand requirements\nUtilize good analytical skills in order to aid in trouble shooting and problem solving\nMust be detail oriented and capable of analyzing issues from end user perspective\nDemonstrate good testing and defect management skills\nDemonstrate a strong understanding of Software Development Life Cycle and specifically QA process and test methodologies\nExperience creating test plans, test scenarios, test scripts & defect management required\nShould be able to work under tight deadlines and  ...
#  'Job Description :\nStandardisation of Processes across the zone\nImplementation of Initiatives championed by 1 city to other cities of the zone\nLead Lean process thinking and design & implement projects in close coordination with central and city knowledge workers to improve targeted metrics\nLiaise with multiple stakeholders to drive projects to improve control and efficiency of the system Responsible for analyzing, structuring and solving select business problems with various teams',
#  'Technical\nMumbai\nPosted : Today\nJob Type: Full-time\nWhat will you do (Job Description)?\nPlay the pivotal role of understanding and gathering project requirements and help the technology team to understand and deliver the project\nTo understand the functional and technical issues, gather all relevant information and take it forward with the technology team\nUnderstanding, consolidating and analyzing Data from spreadsheets/ other sources\nPlay a key role to drive the requirement analysis phase. Should get involved in activities like functional specification document, wireframing, etc.\nWhat do we look for (Required Skills)?\nPassionate, self-motivated, team player\nStrong verbal and written communication skills required\nShould have task management and motivational skills\nGood to Have\nKnowledge of programming will be an advantage\nNegotiation Skills, Problem Solving attitude\nA dynamic person with a drive to achieve closures and clean timely deliveries\nKnowledge of AGILE/SDLC will be an advantage\nExperience in Ecommerce industry will be an added advantage',
# ...
#  'Associate Consultant, Consultant - Risk Advisory Services\n\nThe opportunity\n\nThe objective of our advisory risk services is to provide clients with a candid and reliable overview of their risk landscape. Our solutions can be used by our clients to build confidence and trust with their customers, the overall market and when required by regulation or contract. You will be responsible for executing client related engagements in the areas of internal audits, risk assurance, risk transformation and financial services risk management.\n\nYour key responsibilities\nResponsible for effectively engaging with clients and executing engagements (as detailed out below) under the supervision of Seniors and Managers\nClient Engagements primarily in the areas of Business Risk services like Internal audit, Enterprise Risk management, Compliance risk and regulatory services, Internal controls , Contract Risk Services, Business Process Management and other related solutions\nDrive innovation in service delivery; ensure delivery is in line with firm’s Quality and Risk management requirements/expectations\nAssist Seniors and Managers with business development proposals on existing / new clients\nAssist Seniors and Managers in developing/refreshing methodologies related to our existing/new solutions\nContribute to various firm wide initiatives like learning and development (L&D) programmes, campus recruitment, knowledge sharing, practice development and growth under guidance of Managers\nTake up project execution responsibility in a team or individually as per requirements and work plan\nReview work done by sub-ordinates (if any) and provide qualitative inputs before submission of deliverables to seniors/client (as the case may be)\nSensitive towards EY code of conduct, values and quality standards\n\nSkills and attributes for success\nContinuously strive towards achieving goals agreed upon with Manager\nContinuously strive towards exceeding client & team expectations and work on increasingly complex assignments\nConduct research and prepare client presentations, information memorandums and contribute to thought leadership documents\nContribute to advisory engagements in the capacity of a team member - deliver quality output within assigned timelines\nEnsure discipline to work and productivity of self and reporting subordinates ; promotes positive working environment within a team\nAttend L&D programs and exhibit knowledge of advisory methodology and consulting attributes.\nKeep abreast with developments in business related areas and assist team leaders/managers in preparing client decks/documents.\nSector focus (basic understanding of the industry, trends, issues/challenges & key players) based on the industry group alignment\n\nTo qualify for the role you must have\nChartered Accountant - Nov’18 (qualified) & May’18 (awaiting results)\nExhibit initiative and participate in corporate social and team events\nExhibit flexibility to adapt to multiple cultures / sectors and display agility and diversity\nDemonstrate capability of being a ‘quick learner’ of business processes, models, EY methodologies with an analytical bend of mind\nDisplay a structured thought process and problem solving skills. Ability to do problem break down and analysis\nIdeally, you’ll also have\nCandidates should be willing to travel\nFlexibility to work back in teams with diverse background\nGood Interpersonal and communication skills\nIT Savvy\nWhat we look for\n\nWe’re looking for passionate leaders with strong vision and a desire to stay on top of trends in the risk industry. If you have a genuine passion for helping businesses achieve their full potential, this role is for you.\nWhat working at EY offers\nEY is committed to being an inclusive employer and we are happy to consider flexible working arrangements. We strive to achieve the right balance for our people, enabling us to deliver excellent client service whilst allowing you to build your career without sacrific ...
#  "You'll make an impact by\nHelping the team manage fraud loss line of ~$0.5 billion across Credit & Debit card portfolios and make a direct financial impact to the firm\nDeveloping medium to complex analytical fraud risk strategies on Big Data platforms leveraging statistical techniques and implementation of machine learning models\nEnd to End ownership and accountability of key portfolio segments to mitigate fraud losses and enhance customer experience\nAssist team in managing critical score upgrades that influence strategy outcomes by working with internal / external modeling partners or vendors\nOn-going engagement with senior leaders within Operations and Risk groups\nEffective collaboration with Modeling, Operations, Tech and Finance teams to build best in class industry leading solutions and fraud loss mitigation capabilities\nAbout you\nThe points below have been carefully considered as being essential for the role. Your background must accurately reflect all of these, with or without a reasonable accommodation, for your application to be considered.\nMaster's degree in relevant technical or quantitative fields (e.g., Mathematics, Engineering, Finance, Business, Statistics, Operations Research and Economics)\nStrong analytical, technical, statistical skills and problem solving skills\nAbility to synthesize / analyze diverse information, develops recommendations, and makes decisions.\nStrong communication and interpersonal skills with ability to interact with individuals across departments / functions and with senior-level individuals\nGood multi-tasking skills with ability to manage and prioritize projects across cross-functional groups\nAbility to thrive in a dynamic and fast-paced energetic environment\nTechnical skills - Python / Hive, SAS, SQL, Unix and/or other Oracle and/or Teradata database tools) PowerPoint, Excel required\nKnowledge of Big Data and Machine Learning techniques is a plus\nWe recognize that our people are our strength and the diverse talents they bring to our global workforce is directly linked to our success. We are an equal opportunity employer and place a high value on diversity and inclusion at our company. We do not discriminate on the basis of any protected attribute, including race, religion, color, national origin, gender, sexual orientation, gender identity, gender expression, age, marital or veteran status, or disability, or any other basis protected under applicable local law. In accordance with applicable local law, we make reasonable accommodations for applicants' and employees' religious practices and beliefs, as well as any mental health or physical disability needs.JPMorgan Chase & Co., one of the oldest financial institutions, offers innovative financial solutions to millions of consumers, small businesses and many of the world's most prominent corporate, institutional and government clients under the J.P. Morgan and Chase brands. Our history spans over 200 years and today we are a leader in investment banking, consumer and small business banking, commercial banking, financial transaction processing and asset management.\nWe recognize that our people are our strength and the diverse talents they bring to our global workforce are directly linked to our success. We are an equal opportunity employer and place a high value on diversity and inclusion at our company. We do not discriminate on the basis of any protected attribute, including race, religion, color, national origin, gender, sexual orientation, gender identity, gender expression, age, marital or veteran status, pregnancy or disability, or any other basis protected under applicable law. In accordance with applicable law, we make reasonable accommodations for applicants' and employees' religious practices and beliefs, as well as any mental health or physical disability needs.",
#  'As a business analyst, you will be a leading contributor in the implementation of various projects in Data Collections team. This role requires significant interaction with both upstream and downstream stakeholders across Technology, Data, Products, Sales/Service, and Research.\nWe are looking for an individual who possesses strong domain expertise in data collection domain, an ability to follow data analyst’s requirements and write user stories to implement the projects like enhancements/addition of new dataset, data next gen implementation etc.\nThis position reports to the Tech Manager of the Data Collections.\nResponsibilities :\n• Work within an Agile software development framework, develop business requirements and user stories refined and validated with customers and stakeholders, prioritize the backlog queue across multiple projects and workstreams, and ensure high quality execution working with development and business analyst squad members.\nWork with internal project stakeholders to define and document project scope, plan product phases/ versions, Minimum Viable Product, and overall product deliveries\nWork with other product owners from across the data collection organization to develop a product integration vision that supports and advances their business goals\nWork with cross-functional leaders to determine technology, design, and project management resource requirements to execute and delivery on commitments. Proactively communicate project delivery risks to key stakeholders to ensure timely deliverables\nOwn the tactical roadmap, requirements, and product development lifecycle for a squad to deliver high performing data collection applications to our clients\nUnderstand business, operations and technology requirements, serving as a conduit between stakeholders, operations, and technology teams\nRequirements :\n5+ years of working experience as Business Analyst for managing products/applications catering to equity data collection\nGood understanding of equity fundamental and non-fundamental datasets like financial statement, notes to account, company, personnel and price etc.\nUtilizes user research, product usage data, client services, sales and direct user interactions to identify unmet user needs and opportunities for improvement\nShould have working experience on creating Product Roadmap, Project Scope, Requirement Gathering and documenting\nShould have experience in working with different teams – Global product manager(s), development team(s), test team(s), product stakeholders\nWorking Agile Experience – Scrum methodology, JIRA or equivalent story writing tool, Product Backlog, Sprint Backlog, Story Estimation and Prioritization, creation of user stories, acceptance criteria\nActs as voice of the user within the development organization\nShould be able to clearly communicate the benefits of the product, discovery questions to ask, and answer "the why" to prospective clients\nUtilizes user research, product usage data, client services, direct user interactions to identify unmet user needs and opportunities for improvement\nA bachelor\'s degree is required; CFA or an equivalent certification will be an advantage\nA demonstrated ability to complete analysis and document requirements for multiple complex projects concurrently\nExcellent communication and strong inter-personal skills, time management/organization, and troubleshooting, good analytical and problem-solving skills\nA proven record in supporting large projects with aggressive timelines and wide, challenging scope.\nSelf-directed and detail-oriented.\nStrong knowledge of software development processes and methodologies\nGood to Have :\nExperience in capital market or financial services industry\nEOE Statement : Morningstar is an equal opportunity employer\nI10_MstarIndiaPvtLtd Morningstar India Private Ltd. (Delhi) Legal Entity',
#  'We are looking out for Sr. Business Analysts who are technically sound with good communication skills and a close fit to the job description below:\nPrimary (Essential) Technical Skills desired:\nSkilled in requirement gathering and articulating\nShould have knowledge creating Requirement documents and Functional Test case documents\nExecuting Functional testing and reporting defects\nTaking responsibility of the solution to be delivered to the customers using our product offering, from the requirement confirmation stage up to the final customer acceptance stage\nCarry out customer business requirement analysis using Requirement Workshops, Conference Room Pilots\nConceptualize the solution using our product offering to meet the requirements of the customer\nDiscuss, present to customer scenarios to the customer of solutions to meet the requirements of the customer. Get customer to agree on a chosen scenario\nLead the development team to build the proposed solution using the available product offering\nLead the engagement team to get the final solution tested and approved\nSoft / Behavioral Skills:\nAnalytical skills to carry out sessions with the customer personnel to think through proposed solution\nAbility to conceptualize\nGood written and oral communication\nAbility to interact with the senior management of the customer\nAbility to lead a team of development members\nOverall management skills to ensure the customer relationships remain under control\nConfident, Responsible and High Initiative Driven\nStrong in problem solving and quick in decision making\nEducational Qualification:\nMBA / MMS / PGDBA (mandatory first class throughout in academics)\nExperience:\n5 to 9 years\nJob Location:\nMumbai / Pune (May get posted at client site across the world during the period of assignment. The job may involve travel.)',
#  'We are looking out for Business Analysts who are technically sound with good communication skills and a close fit to the job description below:\nPrimary (Essential) Technical Skills desired:\nSkilled in requirement gathering and articulating\nShould have knowledge creating Requirement documents and Functional Test case documents\nExecuting Functional testing and reporting defects\nTaking responsibility of the solution to be delivered to the customers using our product offering, from the requirement confirmation stage up to the final customer acceptance stage\nCarry out customer business requirement analysis using Requirement Workshops, Conference Room Pilots\nConceptualize the solution using our product offering to meet the requirements of the customer\nDiscuss, present to customer scenarios to the customer of solutions to meet the requirements of the customer. Get customer to agree on a chosen scenario\nLead the development team to build the proposed solution using the available product offering\nLead the engagement team to get the final solution tested and approved\nSoft / Behavioral Skills:\nAnalytical skills to carry out sessions with the customer personnel to think through proposed solution\nAbility to conceptualize\nGood written and oral communication\nAbility to interact with the senior management of the customer\nAbility to lead a team of development members\nOverall management skills to ensure the customer relationships remain under control\nConfident, Responsible and High Initiative Driven\nStrong in problem solving and quick in decision making\nEducational Qualification:\nMBA / MMS / PGDBA (mandatory first class throughout in academics)\nExperience:\n2 to 5 years\nJob Location:\nMumbai / Pune (May get posted at client site across the world during the period of assignment. The job may involve travel.)',
#  'Understand the client process and associated data to help the project team with actionable insights\nDocumenting client requirement and create scope and BRD documents\nCreate project planner and sending out regular updates after taking follow up\nUnderstanding the use cases and process details and coming up with business solutions\nSupport the project team with stunning data visualization for client presentations\nPrepare the power point readouts with analysis to the clients']

# %%
import pandas as pd

# %%
df=pd.DataFrame({})

# %%
df['Titles']=titles
df['Companies']=companies
df['Locations']=locations
df['Links']=links
df['Ratings']=ratings
df['Salaries']=salaries
df['Descriptions']=descriptions
df['Urgent Hiring']=Hir
df["time"]=time
df["date"]=dt

# %%
df
# Out:
#                                                 Titles  \
# 0                                     Business Analyst
# 1                   Business Analyst - Strategy Office
# 2                                     Business Analyst
# 3    Analyst - Business Consulting Risk - TMT - Ris...
# 4      Newgen Software Technologies - Business Analyst
# ..                                                 ...
# 164   Strategic Business Analyst I - DC & CLAIMS FRAUD
# 165                                   Business Analyst
# 166                         SR. BUSINESS ANALYST : SBA
# 167                              BUSINESS ANALYST : BA
# 168                Business Analyst - Speech Analytics
#
#                                      Companies            Locations  \
# 0                      Mirum Digital Pvt. Ltd.  Mumbai, Maharashtra
# 1    Avanse Financial Services Private Limited                 None
# 2                                   Datamatics  Mumbai, Maharashtra
# 3                                Ernst & Young  Mumbai, Maharashtra
# 4                 Newgen Software Technologies  Mumbai, Maharashtra
# ..                                         ...                  ...
# 164                  JPMorgan Chase Bank, N.A.  Mumbai, Maharashtra
# 165                                Morningstar  Mumbai, Maharashtra
# 166                                    C2L Biz  Mumbai, Maharashtra
# 167                                    C2L Biz  Mumbai, Maharashtra
# 168                                      Sitel  Mumbai, Maharashtra
#
#                                                  Links Ratings  \
# 0    https://in.indeed.com/rc/clk?jk=7fedabcef27ecf...    None
# 1    https://in.indeed.com/pagead/clk?mo=r&ad=-6NYl...    None
# 2    https://in.indeed.com/rc/clk?jk=2dd3f14eee66e6...     3.5
# 3    https://in.indeed.com/rc/clk?jk=8d97437977fb02...     4.0
# 4    https://in.indeed.com/company/Newgen-Software-...     3.5
# ..                                                 ...     ...
# 164  https://in.indeed.com/rc/clk?jk=031a12d7cf931f...     3.9
# 165  https://in.indeed.com/rc/clk?jk=24dabee9aad56b...     3.9
# 166  https://in.indeed.com/rc/clk?jk=f08c06c151d631...    None
# 167  https://in.indeed.com/rc/clk?jk=9d387a5b467efb...    None
# 168  https://in.indeed.com/rc/clk?jk=dbf3cd77cac827...     3.5
#
#              Salaries                                       Descriptions  \
# 0    ₹7,00,000 a year  Responsibilities\nPerson will be responsible f...
# 1                None  Job Description\nPlay CEO’s office Business Pa...
# 2                None  Job Code :\nMRF/IT-5805/2020\nExperience :\n4....
# 3                None  About EY\nAs a global leader in assurance, tax...
# 4                None  Designation:\nBusiness System Analyst\nJob Loc...
# ..                ...                                                ...
# 164              None  You'll make an impact by\nHelping the team man...
# 165              None  As a business analyst, you will be a leading c...
# 166              None  We are looking out for Sr. Business Analysts w...
# 167              None  We are looking out for Business Analysts who a...
# 168              None  Understand the client process and associated d...
#
#     Urgent Hiring      time      date
# 0            none  17:50:33  21-01-11
# 1            none  17:50:33  21-01-11
# 2            none  17:50:33  21-01-11
# 3            none  17:50:34  21-01-11
# 4            none  17:50:34  21-01-11
# ..            ...       ...       ...
# 164          none  17:51:03  21-01-11
# 165          none  17:51:03  21-01-11
# 166          none  17:51:04  21-01-11
# 167          none  17:51:04  21-01-11
# 168          none  17:51:04  21-01-11
#
# [169 rows x 10 columns]

# %%
df.to_csv('indeed_crawling_BA_proj3.csv')
